# %%
nome = "ANA"
print(nome.lower())
# Out:
# ana

# %%
nome = input("digite seu nome:")
print(nome.lower())
# Out:
# digite seu nome:IRINEU
# irineu

# %%
nome = input("digite seu nome:")
print(nome.upper())
# Out:
# digite seu nome:joaozinho
# JOAOZINHO

# %%
nome = input("digite seu nome:")
print(nome.strip())
# Out:
# digite seu nome:joana
# joana

# %%
texto = "OLA JOAOZINHO"
print(texto.replace("JOAOZINHO","MARIA"))
# Out:
# OLA MARIA

# %%
nome = input("Digite seu nome:")
print(len(nome))
# Out:
# Digite seu nome:ivesao
# 6

# %% [markdown]
# Atividades

# %%
#Tratamento de dados do usuario
nome = " MARIA EDUARDA ALMEIDA "
email = " MARIA.ALMEIDA@EMPRESA.COM "
1#Retirar espaços desnecessarios
nome =nome.strip()
email = email.strip()
print (nome.strip())
print(email.strip())
2#converter para minusculo
print(nome.lower())
print(email.lower())
3#Substituição automatica
print(email.replace("EMPRESA.COM","gmail.com"))
4#Quantidade de caracteres (sem espaços)
print(len(nome))
5#exibição de caracteres epecificos
ultima_letra = nome[-1]
print(ultima_letra)
primeira_letra = nome[0]
print(primeira_letra)
# Out:
# MARIA EDUARDA ALMEIDA
# MARIA.ALMEIDA@EMPRESA.COM
# maria eduarda almeida
# maria.almeida@empresa.com
# MARIA.ALMEIDA@gmail.com
# 21
# A
# M

# %% [markdown]
# Atividade 2

# %%
#tratamento de dados de produto
produto = "NOTEBOOK DELL INSPIRON"
categoria = "INFORMATICA"
codigo = "ABC-123-XYZ"
1#REMOVER ESPAÇOS
produto = produto.strip()
categoria = categoria.strip()
codigo = codigo.strip()
print(produto)
print(categoria)
print(codigo)
2#Conversao para minusculo
print(categoria.lower())
3#Padronização
print(codigo.replace("ABC-123-XYZ","ABC123XYZ"))
4#QUANTIDA DE CARACTERES
print(len(produto))
5#exibir letras especificas
primeira_letra = produto[0]
caracteres_do_codigo = codigo[0:5]
print(primeira_letra)
print(caracteres_do_codigo)
# Out:
# NOTEBOOK DELL INSPIRON
# INFORMATICA
# ABC-123-XYZ
# informatica
# ABC123XYZ
# 22
# N
# ABC-1
