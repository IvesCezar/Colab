# %%
#Exemplos
idade = int(input("Digite a sua idade:"))

if idade >= 18:
  print("Você é maior de idade")
else:
  print("Você é menor de idade")
#-------------------------------------------------------------------------------
# Out:
# Digite a sua idade:19
# Você é maior de idade

# %%
idade = int(input("Digite a sua idade:"))

if idade < 16:
  print("Você é menor de idade")
elif idade >= 16 and idade < 18:
  print("Voto opicional")
# Out:
# Digite a sua idade:10
# Você é menor de idade

# %%
#Atividade 1
metodo_pagamento = input("Digite o método de pagamento (cartao/boleto): ")

if metodo_pagamento == "cartao":
  print("Processando pagamento no cartão...")
elif metodo_pagamento == "boleto":
  print("Gerando boleto bancário...")
else:
  print("Método de pagamento não reconhecido.")
# Out:
# Digite o método de pagamento (cartao/boleto): dinheiro
# Método de pagamento não reconhecido.

# %%
#Atividade 2
idade = int(input("Digite a sua idade:"))

if idade <= 12:
  print("Criança")
elif idade >= 13 and idade <= 17:
  print("Adolescente")
elif idade >= 18 and idade <= 59:
  print("Adulto")
else:
  print("Idoso")
# Out:
# Digite a sua idade:60
# Idoso

# %%
#Atividade 3
entrega = input("Digite o tipo de entrega:")
if entrega == "Padrão":
  print("entrega padrão R$10,00")
elif entrega == "expresso":
  print("entrega expresso R$20,00")
else:
  print("opcão de entrega invalida")
# Out:
# Digite o tipo de entrega:n
# opcão de entrega invalida
